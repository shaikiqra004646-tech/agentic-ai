# %%
import os
os.environ['ANTHROPIC_API_KEY'] = 'your-key-here'
api_key = os.environ['ANTHROPIC_API_KEY']

# %%
# !pip install anthropic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 923.9/923.9 kB 13.6 MB/s eta 0:00:00
# ...

# %%
pip install google-genai

# %%
import os
from google import genai


os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6KwRh2Fe2rLxPsttzR8s7nYUkT4jGVtVr0rj-t4XzLw4A"

# Create client
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])
knowledge_base = """
KSRM College of Engineering is located in Kadapa.
The AIML department was established to teach Artificial Intelligence and Machine Learning.
Python is a popular programming language for ML.
Machine Learning uses data to learn patterns.
Deep Learning is a subset of Machine Learning.
"""
# Generate response
question = input("Ask a question: ")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=f"""
Use only the following information to answer.

{knowledge_base}

Question: {question}
"""
)

print(response.text)
# Out:
# Ask a question: what is deep learning
# Deep Learning is a subset of Machine Learning.
