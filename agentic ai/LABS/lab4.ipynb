# %% [markdown]
# LAB-4:
# n Lab: Explore a real dataset– answer 10 questions with Pandas

# %%
import pandas as pd

df = pd.read_csv("ipl.csv")

# %% [markdown]
# 1. Display first 5 rows

# %%
print(df.head())
# Out:
#   Player  Runs Team
# 0  Virat   973  RCB
# 1  Rohit   850   MI
# 2  Dhoni   650  CSK
# 3   Gill   890   GT

# %% [markdown]
# 2. Number of rows and columns

# %%
print(df.shape)
# Out:
# (4, 3)

# %% [markdown]
# 3. List all column names

# %%
print(df.columns)
# Out:
# Index(['Player', 'Runs', 'Team'], dtype='object')

# %% [markdown]
# 4. Display only Player column

# %%
print(df["Player"])
# Out:
# 0    Virat
# 1    Rohit
# 2    Dhoni
# 3     Gill
# Name: Player, dtype: object

# %% [markdown]
# 5. Find player with highest runs

# %%
print(df.loc[df["Runs"].idxmax()])
# Out:
# Player    Virat
# Runs        973
# Team        RCB
# Name: 0, dtype: object

# %% [markdown]
# 6. Find player with lowest runs

# %%
print(df.loc[df["Runs"].idxmin()])
# Out:
# Player    Dhoni
# Runs        650
# Team        CSK
# Name: 2, dtype: object

# %% [markdown]
# 7. Average runs

# %%
print(df["Runs"].mean())
# Out:
# 840.75

# %% [markdown]
# 8. Total runs scored

# %%
print(df["Runs"].sum())
# Out:
# 3363

# %% [markdown]
# 9. Players scoring above 800 runs

# %%
print(df[df["Runs"] > 800])
# Out:
#   Player  Runs Team
# 0  Virat   973  RCB
# 1  Rohit   850   MI
# 3   Gill   890   GT

# %% [markdown]
# 10. Count players in each team

# %%
print(df["Team"].value_counts())
# Out:
# Team
# RCB    1
# MI     1
# CSK    1
# GT     1
# Name: count, dtype: int64
