# %%
LAB-3:
 Student report card system - read CSV, compute grades, write output

# %%
import csv

def calculate_grade(marks):
    if marks >= 90:
        return "A"
    elif marks >= 75:
        return "B"
    elif marks >= 60:
        return "C"
    else:
        return "D"

try:
    with open("/students.csv", "r") as file:
        reader = csv.DictReader(file)

        print("Student Report Card")
        print("-" * 30)
        print("Name\tMarks\tGrade")

        for row in reader:
            marks = int(row["Marks"])
            grade = calculate_grade(marks)

            print(f"{row['Name']}\t{marks}\t{grade}")

except FileNotFoundError:
    print("Input file not found.")

except Exception as e:
    print("Error:", e)
# Out:
# Student Report Card
# ------------------------------
# Name	Marks	Grade
# Ravi	85	B
# Sita	92	A
# Ram	65	C
